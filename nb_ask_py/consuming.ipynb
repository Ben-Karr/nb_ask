# %%
import httpx
from pprint import pprint
import json

# %%
ret = httpx.get("http://localhost:3000/")
cell_content = ret.json()
cell_content[1]
# Out:
# {'index': 1,
#  'kind': 'code',
#  'source': 'ret = httpx.get("http://localhost:3000/")\ncell_content = ret.json()\ncell_content[1]',
#  'outputs': []}
