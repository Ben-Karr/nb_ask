# %%
from fastcore import tools
import dialoghelper
from cellm import ask
from cellm.core import chat

# %%
ask??
# Out:
# Signature: ask(pr: str)
# Docstring: <no docstring>
# Source:
# def ask(pr: str):
#     cells_content = json.dumps(get_cells())
#     chat.hist = [f"active notebook content: {cells_content}"]
#     resp = chat(pr)
#     chat.last_response = resp
#
#     model_name = chat.model.split("/")[-1]
#     header = f"##### 🤖 LLM Response ({model_name} | in: {resp.usage.prompt_tokens} | out: {resp.usage.completion_tokens})\n\n> "
#     quoted = resp.choices[0].message.content.replace("\n", "\n> ")
#     insert_cell(header + quoted)
# File:      ~/code/nb_ask/nb_ask_py/src/cellm/core.py
# Type:      function

# %%
type(chat)
# Out:
# lisette.core.Chat

# %%
ask("I want to provide tools for my chat instance, lets assume a simple read_file to give you access to file contents, what do i need to do?")
# Out:
# 17:26:52 - LiteLLM:WARNING: utils.py:2730 - register_model: model=openrouter/z-ai/glm-5.2 not in built-in cost map and no prefix/region variant matched; cache cost fields will default to 0. To track cache cost, add cache_creation_input_token_cost and cache_read_input_token_cost to model_info

# %%
ask("Can i just update the tools list from chat at runtime, or do i have to reinitialize?")

# %% [markdown]
# ##### 🤖 LLM Response (glm-5.2 | in: 1140 | out: 32)
#
# > You can usually just assign to it directly: `chat.tools = [read_file]`. Try it and see if the next call picks it up.
