# %%
from cellm.core import get_cells

# %% [markdown]
# * Hey how ar itrnaeihaefgih
# * iafehifgaeh
#   * itranetrianetrn
#   * fghlvfgchfgaie
# * itaefghafge

# %%
#banana
get_cells()
# Out:
# [{'index': 0,
#   'kind': 'code',
#   'source': 'from cellm.core import get_cells',
#   'outputs': []},
#  {'index': 1,
#   'kind': 'markdown',
#   'source': '* Hey how ar itrnaeihaefgih\n* iafehifgaeh\n  * itranetrianetrn\n  * fghlvfgchfgaie\n* itaefghafge',
#   'outputs': []}]

# %%
#apple
get_cells()
# Out:
# []
